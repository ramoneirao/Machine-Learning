# %%
import pandas as pd
pd.set_option("display.width", 320)
df = pd.read_csv('2015-building-energy-benchmarking.csv')
pd.set_option('display.max_columns', 42)
df.head()
# Out:
#    OSEBuildingID  DataYear    BuildingType PrimaryPropertyType           PropertyName TaxParcelIdentificationNumber                                           Location  CouncilDistrictCode Neighborhood  YearBuilt  NumberofBuildings  NumberofFloors  PropertyGFATotal  PropertyGFAParking  PropertyGFABuilding(s)  \
# 0              1      2015  NonResidential               Hotel   MAYFLOWER PARK HOTEL                     659000030  {'latitude': '47.61219025', 'longitude': '-122...                    7     DOWNTOWN       1927                  1            12.0             88434                   0                   88434
# 1              2      2015  NonResidential               Hotel        PARAMOUNT HOTEL                     659000220  {'latitude': '47.61310583', 'longitude': '-122...                    7     DOWNTOWN       1996                  1            11.0            103566               15064                   88502
# 2              3      2015  NonResidential               Hotel           WESTIN HOTEL                     659000475  {'latitude': '47.61334897', 'longitude': '-122...                    7     DOWNTOWN       1969                  1            41.0            961990                   0                  961990
# 3              5      2015  NonResidential               Hotel              HOTEL MAX                     659000640  {'latitude': '47.61421585', 'longitude': '-122...                    7     DOWNTOWN       1926                  1            10.0             61320                   0                   61320
# 4              8      2015  NonResidential               Hotel  WARWICK SEATTLE HOTEL                     659000970  {'latitude': '47.6137544', 'longitude': '-122....                    7     DOWNTOWN       1980                  1            18.0            119890               12460                  107430
#
#        ListOfAllPropertyUseTypes LargestPropertyUseType  LargestPropertyUseTypeGFA SecondLargestPropertyUseType  SecondLargestPropertyUseTypeGFA ThirdLargestPropertyUseType  ...  SourceEUI(kBtu/sf) SourceEUIWN(kBtu/sf)  SiteEnergyUse(kBtu)  SiteEnergyUseWN(kBtu)  SteamUse(kBtu)  Electricity(kWh)  Electricity(kBtu)  \
# 0                          Hotel                  Hotel                    88434.0                          NaN                              NaN                         NaN  ...               173.5                175.1            6981428.0              7097539.0       2023032.0         1080307.0          3686160.0
# 1     Hotel, Parking, Restaurant                  Hotel                    83880.0                      Parking                          15064.0                  Restaurant  ...               191.3                195.2            8354235.0              8765788.0             0.0         1144563.0          3905411.0
# 2  Hotel, Parking, Swimming Pool                  Hotel                   757243.0                      Parking                         100000.0               Swimming Pool  ...               242.7                246.5           73130656.0             75506272.0      19660404.0        14583930.0         49762435.0
# 3                          Hotel                  Hotel                    61320.0                          NaN                              NaN                         NaN  ...               636.3                643.2           28229320.0             28363444.0      23458518.0          811521.0          2769023.0
# 4  Hotel, Parking, Swimming Pool                  Hotel                   123445.0                      Parking                          68009.0               Swimming Pool  ...               228.8                227.1           14829099.0             15078243.0             0.0         1777841.0          6066245.0
#
#    NaturalGas(therms)  NaturalGas(kBtu)  OtherFuelUse(kBtu)  GHGEmissions(MetricTonsCO2e)  GHGEmissionsIntensity(kgCO2e/ft2)  DefaultData  Comment  ComplianceStatus       Outlier  2010 Census Tracts Seattle Police Department Micro Community Policing Plan Areas City Council Districts SPD Beats Zip Codes
# 0             12724.0         1272388.0                 0.0                        249.43                               2.64           No      NaN         Compliant           NaN                 NaN                                               14.0                               NaN      31.0     18081
# 1             44490.0         4448985.0                 0.0                        263.51                               2.38           No      NaN         Compliant           NaN                 NaN                                               14.0                               NaN      31.0     18081
# 2             37099.0         3709900.0                 0.0                       2061.48                               1.92          Yes      NaN         Compliant           NaN                 NaN                                               56.0                               NaN      31.0     18081
# 3             20019.0         2001894.0                 0.0                       1936.34                              31.38           No      NaN         Compliant  High Outlier                 NaN                                               56.0                               NaN      31.0     18081
# 4             87631.0         8763105.0                 0.0                        507.70                               4.02           No      NaN         Compliant           NaN                 NaN                                               56.0                               NaN      31.0     19576
#
# [5 rows x 47 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
sns.heatmap(df.corr())
plt.show()
